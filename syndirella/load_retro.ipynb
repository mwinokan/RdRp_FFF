# %%
import pandas as pd

# %%
df = pd.read_pickle("fstein_cavity_b/output/justretroquery_fstein_cavity_b_syndirella_input.pkl.gz")
df
# Out:
#                                 smiles  \
# 0        COc1ccc2cc(CN)[nH]c2c1NC(C)=O
# 1  CC(=O)N(c1ccn[nH]1)c1cccc2cc[nH]c12
# 2    CC1CN2C3=C(CCC(NC(=O)CN)C3)OC2CN1
# 3    CC1CN2C3=C(CCC(NC(=O)CN)C3)OC2CN1
# 4    CC1CN2C3=C(CCC(NC(=O)CN)C3)OC2CN1
# 5    CC1CN2C3=C(CCC(NC(=O)CN)C3)OC2CN1
# 6                CCOc1c(F)c(OCF)cn1CCO
#
#                                             template     compound_set    hit1  \
# 0  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0136b
# 1  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0136b
# 2  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0184a
# 3  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0184a
# 4  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0184a
# 5  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0184a
# 6  /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGET...  fstein_cavity_b  z0767a
#
# ...
